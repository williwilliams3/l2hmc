# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from utils.func_utils import accept, jacobian, autocovariance, get_log_likelihood, \
    get_data, binarize, normal_kl, acl_spectrum, ESS
from utils.distributions import Gaussian, GMM, GaussianFunnel, gen_ring
from utils.layers import Linear, Sequential, Zip, Parallel, ScaleTanh
from utils.dynamics import Dynamics
from utils.sampler import propose
from utils.notebook_utils import get_hmc_samples

# %% [markdown]
# ## Network architecture
#
# We define the network architecture for our L2HMC network. We first embed the first two variables ($\{x, \partial_x U\}$ or $\{v, x_m\}$) as well as the time, formatted as $\tau(t) = \left(\cos(\frac{2\pi t}{M}), \sin(\frac{2\pi t}{M})\right)$. They are forwarded through an MLP and then produce $S, T$ and $Q$.

# %%
def network(x_dim, scope, factor):
    with tf.variable_scope(scope):
        net = Sequential([
            Zip([
                Linear(x_dim, 10, scope='embed_1', factor=1.0 / 3),
                Linear(x_dim, 10, scope='embed_2', factor=factor * 1.0 / 3),
                Linear(2, 10, scope='embed_3', factor=1.0 / 3),
                lambda _: 0.,
            ]),
            sum,
            tf.nn.relu,
            Linear(10, 10, scope='linear_1'),
            tf.nn.relu,
            Parallel([
                Sequential([
                    Linear(10, x_dim, scope='linear_s', factor=0.001), 
                    ScaleTanh(x_dim, scope='scale_s')
                ]),
                Linear(10, x_dim, scope='linear_t', factor=0.001),
                Sequential([
                    Linear(10, x_dim, scope='linear_f', factor=0.001),
                    ScaleTanh(x_dim, scope='scale_f'),
                ])
            ])  
        ])
        
    return net

# %% [markdown]
# ## Distribution
#
# We define our energy function. It is a Gaussian distribution with zero mean. The covariance is a $\pi/4$ rotation of the eigenvalues $[100, 10^{-1}]$. We set up our dynamics which take as input our energy function, the number of time step of our operator, the (learnable) step-size and our architecture.

# %%
x_dim = 2
distribution = GaussianFunnel()
dynamics = Dynamics(x_dim, distribution.get_energy_function(), T=8, eps=0.1, net_factory=network)
# Out:
# getting energy fn
# WARNING:tensorflow:From /Users/williber/git-hub/l2hmc/utils/dynamics.py:47: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/williber/git-hub/l2hmc/utils/dynamics.py:50: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /Users/williber/git-hub/l2hmc/utils/dynamics.py:52: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /var/folders/wb/8hr1dfqs2plb2kfsfhfvlnrjjd2305/T/ipykernel_3380/3107178270.py:2: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /Users/williber/git-hub/l2hmc/utils/layers.py:34: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# We can directly sample from this distribution and plot it for sanity-check.

# %%
S = distribution.get_samples(1000)
plt.title('Funnel')
plt.scatter(S[:, 0], S[:, 1])
plt.show()

# %% [markdown]
# We set up the loss on both $p(\xi)$ (here `x`) and $q(\xi)$ (here `z`). We then train with Adam with a learning rate of $10^{-5}$.

# %%
x = tf.placeholder(tf.float32, shape=(None, x_dim))
z = tf.random_normal(tf.shape(x))

Lx, _, px, output = propose(x, dynamics, do_mh_step=True)
Lz, _, pz, _ = propose(z, dynamics, do_mh_step=False)

loss = 0.

v1 = (tf.reduce_sum(tf.square(x - Lx), axis=1) * px) + 1e-4
v2 = (tf.reduce_sum(tf.square(z - Lz), axis=1) * pz) + 1e-4
scale = 0.1

loss += scale * (tf.reduce_mean(1.0 / v1) + tf.reduce_mean(1.0 / v2))
loss += (- tf.reduce_mean(v1) - tf.reduce_mean(v2)) / scale
# Out:
# WARNING:tensorflow:From /var/folders/wb/8hr1dfqs2plb2kfsfhfvlnrjjd2305/T/ipykernel_3380/2698549818.py:2: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /Users/williber/git-hub/l2hmc/utils/sampler.py:36: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/williber/git-hub/l2hmc/utils/distributions.py:176: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/williber/git-hub/l2hmc/utils/dynamics.py:309: The name tf.is_finite is deprecated. Please use tf.math.is_finite instead.

# %%
global_step = tf.Variable(0., name='global_step', trainable=False)
learning_rate = tf.train.exponential_decay(1e-5, global_step, 1000, 0.96, staircase=True)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss, global_step=global_step)
# Out:
# WARNING:tensorflow:From /var/folders/wb/8hr1dfqs2plb2kfsfhfvlnrjjd2305/T/ipykernel_3380/9084550.py:2: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /var/folders/wb/8hr1dfqs2plb2kfsfhfvlnrjjd2305/T/ipykernel_3380/9084550.py:3: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.

# %% [markdown]
# The training loop described in Algorithm $1$.

# %%
n_steps = 1000
n_samples = 200

samples = np.random.randn(n_samples, x_dim)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for t in range(n_steps):
    _, loss_, samples, px_, lr_ = sess.run([
        train_op,
        loss,
        output[0],
        px,
        learning_rate,
    ], {x: samples})

    if t % 100 == 0:        
        print('Step: %d / %d, Loss: %.2e, Acceptance sample: %.2f, LR: %.5f' % (t, n_steps, loss_, np.mean(px_), lr_))
# Out:
# WARNING:tensorflow:From /var/folders/wb/8hr1dfqs2plb2kfsfhfvlnrjjd2305/T/ipykernel_3380/3389636463.py:6: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /var/folders/wb/8hr1dfqs2plb2kfsfhfvlnrjjd2305/T/ipykernel_3380/3389636463.py:7: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# 2023-12-12 12:58:42.001155: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2023-12-12 12:58:42.021603: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7faf59d36360 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-12 12:58:42.021616: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# Step: 0 / 1000, Loss: -2.76e+01, Acceptance sample: 0.97, LR: 0.00001
# Step: 100 / 1000, Loss: -2.17e+01, Acceptance sample: 0.96, LR: 0.00001
# Step: 200 / 1000, Loss: -2.21e+01, Acceptance sample: 0.95, LR: 0.00001
# Step: 300 / 1000, Loss: -2.14e+01, Acceptance sample: 0.93, LR: 0.00001
# Step: 400 / 1000, Loss: -2.10e+01, Acceptance sample: 0.94, LR: 0.00001
# Step: 500 / 1000, Loss: -2.61e+01, Acceptance sample: 0.95, LR: 0.00001
# Step: 600 / 1000, Loss: -2.37e+01, Acceptance sample: 0.94, LR: 0.00001
# Step: 700 / 1000, Loss: -2.62e+01, Acceptance sample: 0.96, LR: 0.00001
# Step: 800 / 1000, Loss: -2.52e+01, Acceptance sample: 0.96, LR: 0.00001
# Step: 900 / 1000, Loss: -2.57e+01, Acceptance sample: 0.95, LR: 0.00001

# %% [markdown]
# After training, we generate $200$ chains for $2000$ steps for evaluation purposes.

# %%
samples = distribution.get_samples(n=n_samples)
final_samples = []

for t in range(2000):
    final_samples.append(np.copy(samples))

    feed_dict = {
        x: samples,
    }

    samples = sess.run(output[0], feed_dict)

# %% [markdown]
# We compute the HMC chains with **auto-correlation spectrums** as well.

# %%
L2HMC_samples = np.array(final_samples)
HMC_samples_1 = get_hmc_samples(2, 0.1, distribution.get_energy_function(), sess, steps=2000, samples=samples)
HMC_samples_2 = get_hmc_samples(2, 0.15, distribution.get_energy_function(), sess, steps=2000, samples=samples)
HMC_samples_3 = get_hmc_samples(2, 0.2, distribution.get_energy_function(), sess, steps=2000, samples=samples)
# Out:
# getting energy fn
# getting energy fn
# getting energy fn

# %%
scale = distribution.sigma
L2HMC = acl_spectrum(L2HMC_samples, scale=scale)
HMC1 = acl_spectrum(HMC_samples_1, scale=scale)
HMC2 = acl_spectrum(HMC_samples_2, scale=scale)
HMC3 = acl_spectrum(HMC_samples_3, scale=scale)

# %% [markdown]
# We can plot auto-correlation.

# %%
xaxis = 10 * np.arange(300)
plt.plot(xaxis, L2HMC[:300], label='L2HMC')
plt.plot(xaxis, HMC1[:300], label='HMC $\epsilon=0.1$')
plt.plot(xaxis, HMC2[:300], label='HMC $\epsilon=0.15$')
plt.plot(xaxis, HMC3[:300], label='HMC $\epsilon=0.2$')
plt.ylabel('Auto-correlation')
plt.xlabel('Gradient Computations')
plt.legend()
plt.show()

# %% [markdown]
# We now compute the **Effective Sample Size** (ESS).

# %%
print ('ESS L2HMC: %.2e -- ESS HMC: %.2e -- Ratio: %d' % (ESS(L2HMC), ESS(HMC2), ESS(L2HMC) / ESS(HMC2)))
# Out:
# ESS L2HMC: 2.65e-03 -- ESS HMC: 9.81e-03 -- Ratio: 0

# %% [markdown]
# We can visualize a single chain of L2HMC for $50$ time steps.

# %%
plt.scatter(S[:, 0], S[:, 1])
plt.plot(L2HMC_samples[:50, 1, 0], L2HMC_samples[:50, 1, 1], color='orange', marker='o', alpha=0.8)
plt.show()

# %%
plt.scatter(L2HMC_samples[:, 1, 0], L2HMC_samples[:, 1, 1], color='orange', marker='o', alpha=0.8)
plt.show()

# %% [markdown]
# #### Histograms

# %%
samples_reshape = L2HMC_samples.reshape(-1, 2)
# Out:
# (2000, 200, 2)
# (400000, 2)

# %%
plt.scatter(samples_reshape[:, 0], samples_reshape[:, 1], color='orange', marker='o', alpha=0.8)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].hist(samples_reshape[:, 0], bins=40, color='orange')
axes[1].hist(samples_reshape[:, 1], bins=40, color='orange')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].hist(S[:, 0], bins=40)
axes[1].hist(S[:, 1], bins=40)
plt.show()
